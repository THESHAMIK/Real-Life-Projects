# %% [markdown]
# <a href="https://colab.research.google.com/github/THESHAMIK/Real-Life-Projects/blob/main/H2O/KHDS_H2O_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!nvidia-smi
# !apt-get install default-jre
# !java -version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# default-jre is already the newest version (2:1.11-68ubuntu1~18.04.1).
# default-jre set to manually installed.
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# openjdk version "11.0.15" 2022-04-19
# OpenJDK Runtime Environment (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1, mixed mode, sharing)

# %%
# !pip install h2o
# Out:
# Collecting h2o
#   Downloading h2o-3.36.1.1.tar.gz (177.0 MB)
#      |████████████████████████████████| 177.0 MB 20 kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from h2o) (2.23.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from h2o) (0.8.9)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from h2o) (0.16.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (1.24.3)
# Building wheels for collected packages: h2o
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.36.1.1-py2.py3-none-any.whl size=177068062 sha256=ce105f224a6f6423ed557d1add17a7053b2e5a7401289dd65cc9f66e80dd76d9
#   Stored in directory: /root/.cache/pip/wheels/a6/d9/ab/5442447c7e2ccf07f66aa8b79f3877ce5382f0b95e6c0c797b
# Successfully built h2o
# Installing collected packages: h2o
# Successfully installed h2o-3.36.1.1

# %%
import h2o
from h2o.automl import H2OAutoML
from google.colab import files

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.15" 2022-04-19; OpenJDK Runtime Environment (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1); OpenJDK 64-Bit Server VM (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.7/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpy34sn_vg
#   JVM stdout: /tmp/tmpy34sn_vg/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpy34sn_vg/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.1
# H2O_cluster_version_age:    28 days, 14 hours and 27 minutes
# H2O_cluster_name:           H2O_from_python_unknownUser_bux1is
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.172 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.13 final
# --------------------------  ----------------------------------

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2a4a4e98-8eba-4e7c-addd-cba8085451cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a4a4e98-8eba-4e7c-addd-cba8085451cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving khds_final_2.csv to khds_final_2.csv

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "khds_final_2.csv" with length 271205 bytes

# %% [markdown]
# khds_final_2.csv has values less than 20 for Product Sulphur.
# khds_final_1.csv had all values even 184.
# Those r now taken off to check for r2.

# %%
# Load data into H2O
df = h2o.import_file("khds_final_2.csv")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
df
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  LABfeed Sulphur</th><th style="text-align: right;">  T1 : FRESH FEED FLOW TO KHDS KGPerHour</th><th style="text-align: right;">  T1 : Reactor inlet temperature DEGC</th><th style="text-align: right;">  T1 : Hydrogen make-up flow NM3perHour</th><th style="text-align: right;">  T1 : Recycle hydrogen flow NM3perHour</th><th style="text-align: right;">  T1 : REACTOR OUTLET Temp DEGC</th><th style="text-align: right;">  T1 : REACTOR FEED INLET Pressure KGperCM2</th><th style="text-align: right;">  T1 : Cold separator pressure KGperCM2</th><th style="text-align: right;">  T1 : KERO FEED DENSITY KGperCM2</th><th style="text-align: right;">  T2 : FRESH FEED FLOW TO KHDS KGPerHour</th><th style="text-align: right;">  T2 : Reactor inlet temperature DEGC</th><th style="text-align: right;">  T2 : Hydrogen make-up flow NM3perHour</th><th style="text-align: right;">  T2 : Recycle hydrogen flow NM3perHour</th><th style="text-align: right;">  T2 : REACTOR OUTLET Temp DEGC</th><th style="text-align: right;">  T2 : REACTOR FEED INLET Pressure KGperCM2</th><th style="text-align: right;">  T2 : Cold separator pressure KGperCM2</th><th style="text-align: right;">  T2 : KERO FEED DENSITY KGperCM2</th><th style="text-align: right;">  T3 : FRESH FEED FLOW TO KHDS KGPerHour</th><th style="text-align: right;">  T3 : Reactor inlet temperature DEGC</th><th style="text-align: right;">  T3 : Hydrogen make-up flow NM3perH
    21.5318</td><td style="text-align: right;">                                18.5701</td><td style="text-align: right;">                          700.446</td><td style="text-align: right;">                                 60844.6</td><td style="text-align: right;">                              269.986</td><td style="text-align: right;">                                627.003</td><td style="text-align: right;">                                15918.6</td><td style="text-align: right;">                        272.423</td><td style="text-align: right;">                                    21.5626</td><td style="text-align: right;">                                18.5992</td><td style="text-align: right;">                          700.712</td><td style="text-align: right;">               20</td></tr>
# <tr><td style="text-align: right;">             1200</td><td style="text-align: right;">                                 60362.2</td><td style="text-align: right;">                              269.971</td><td style="text-align: right;">                                558.112</td><td style="text-align: right;">                                12542.8</td><td style="text-align: right;">                        272.555</td><td style="text-align: right;">                                    21.0184</td><td style="text-align: right;">

# %%
df.types
# Out:
# {'LABfeed Sulphur': 'real',
#  'Product Sulphur': 'real',
#  'T1 : Cold separator pressure KGperCM2': 'real',
#  'T1 : FRESH FEED FLOW TO KHDS KGPerHour': 'real',
#  'T1 : Hydrogen make-up flow NM3perHour': 'real',
#  'T1 : KERO FEED DENSITY KGperCM2': 'real',
#  'T1 : REACTOR FEED INLET Pressure KGperCM2': 'real',
#  'T1 : REACTOR OUTLET Temp DEGC': 'real',
#  'T1 : Reactor inlet temperature DEGC': 'real',
#  'T1 : Recycle hydrogen flow NM3perHour': 'real',
#  'T2 : Cold separator pressure KGperCM2': 'real',
#  'T2 : FRESH FEED FLOW TO KHDS KGPerHour': 'real',
#  'T2 : Hydrogen make-up flow NM3perHour': 'real',
#  'T2 : KERO FEED DENSITY KGperCM2': 'real',
#  'T2 : REACTOR FEED INLET Pressure KGperCM2': 'real',
#  'T2 : REACTOR OUTLET Temp DEGC': 'real',
#  'T2 : Reactor inlet temperature DEGC': 'real',
#  'T2 : Recycle hydrogen flow NM3perHour': 'real',
#  'T3 : Cold separator pressure KGperCM2': 'real',
#  'T3 : FRESH FEED FLOW TO KHDS KGPerHour': 'real',
#  'T3 : Hydrogen make-up flow NM3perHour': 'real',
#  'T3 : KERO FEED DENSITY KGperCM2': 'real',
#  'T3 : REACTOR FEED INLET Pressure KGperCM2': 'real',
#  'T3 : REACTOR OUTLET Temp DEGC': 'real',
#  'T3 : Reactor inlet temperature DEGC': 'real',
#  'T3 : Recycle hydrogen flow NM3perHour': 'real',
#  'T4 : Cold separator pressure KGperCM2': 'real',
#  'T4 : FRESH FEED FLOW TO KHDS KGPerHour': 'real',
#  'T4 : Hydrogen make-up flow NM3perHour': 'real',
#  'T4 : KERO FEED DENSITY KGperCM2': 'real',
#  'T4 : REACTOR FEED INLET Pressure KGperCM2': 'real',
#  'T4 : REACTOR OUTLET Temp DEGC': 'real',
#  'T4 : Reactor inlet temperature DEGC': 'real',
#  'T4 : Recycle hydrogen flow NM3perHour': 'real'}

# %%
df.describe()
# Out:
# Rows:705
# Cols:34
# <table>
# <thead>
# <tr><th>       </th><th>LABfeed Sulphur   </th><th>T1 : FRESH FEED FLOW TO KHDS KGPerHour  </th><th>T1 : Reactor inlet temperature DEGC  </th><th>T1 : Hydrogen make-up flow NM3perHour  </th><th>T1 : Recycle hydrogen flow NM3perHour  </th><th>T1 : REACTOR OUTLET Temp DEGC  </th><th>T1 : REACTOR FEED INLET Pressure KGperCM2  </th><th>T1 : Cold separator pressure KGperCM2  </th><th>T1 : KERO FEED DENSITY KGperCM2  </th><th>T2 : FRESH FEED FLOW TO KHDS KGPerHour  </th><th>T2 : Reactor inlet temperature DEGC  </th><th>T2 : Hydrogen make-up flow NM3perHour  </th><th>T2 : Recycle hydrogen flow NM3perHour  </th><th>T2 : REACTOR OUTLET Temp DEGC  </th><th>T2 : REACTOR FEED INLET Pressure KGperCM2  </th><th>T2 : Cold separator pressure KGperCM2  </th><th>T2 : KERO FEED DENSITY KGperCM2  </th><th>T3 : FRESH FEED FLOW TO KHDS KGPerHour  </th><th>T3 : Reactor inlet temperature DEGC  </th><th>T3 : Hydrogen make-up flow NM3perHour  </th><th>T3 : Recycle hydrogen flow NM3perHour  </th><th>T3 : REACTOR OUTLET Temp DEGC  </th><th>T3 : REACTOR FEED INLET Pressure KGperCM2  </th><th>T3 : Cold separator pressure KGperCM2  </th><th>T3 : KERO FEED DENSITY KGperCM2  </th><th>T4 : FRESH FEED FLOW TO KHDS KGPerHour  </th><th>T4 : Reactor inlet temperature DEGC  </th><th>T4 : Hydrogen make-up flow NM3perHour  </th><th>T4 : Recycle hydrogen flow NM3perHour  </th><th>T4 : REACTOR OUTLET Temp DEGC  </th><th>T4 : REACTOR FEED INLET Pressure KGperCM2  </th><th>T4 : Cold separator pressure KGperCM2  </th><th>T4 : KERO FEED DENSITY KGperCM2  </th><th>Product Sulphur   </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>real              </td><td>real                                    </td><td>real                                 </td><td>real                                   </td><td>real                                   </td><td>real                           </td><td>real                                       </td><td>real                                   </td><td>real                             </td><td>real                                    </td><td>real                                 </td><td>real                                   </td><td>real                                   </td><td>real                           </td><td>real                                       </td><td>real                                   </td><td>real                             </td><td>real                                    </td><td>real                                 </td><td>real                                   </td><td>real                                   </td><td>real                           </td><td>real                                       </td><td>real                                   </td><td>real                             </td><td>real                                    </td><td>real                                 </td><td>real                                   </td><td>real                                   </td><td>real                           </td><td>real                                       </td><td>real                                   </td><td>real                             </td><td>real              </td></tr>
# <tr><td>mins   </td><td>0.1               </td><td>0.0                                     </td><td>0.0                                  </td><td>0.0                                    </td><td>0.0                                    </td><td>0.0                            </td><td>0.0                                        </td><td>0.0                                    </td><td>0.0                              </td><td>0.0                                     </td><td>0.0                                  </td><td>0.0                                    </td><td>0.0                                    </td><td>0.0                            </td><td>0.0                                        </td><td>0.0                                    </td><td>0.0                              </td><td>0.0                                     </td><td>0.0                                  </td><td>0.0                                    </td><td>0.0                                    </td><td>0.0                            </td><td>0.0                                        </td><td>0.0                                    </td><td>0.0                              </td><td>0.0                                     </td><td>0.0                                  </td><td>0.0                                    </td><td>0.0                                    </td><td>0.0                            </td><td>0.0                                        </td><td>0.0                                    </td><td>0.0                              </td><td>0.5               </td></tr>
_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (6g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (10g, 60w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w), best_of_family_2 (2g, 5w), best_of_family_3 (3g, 5w), best_of_family_4 (4g, 5w), best_of_family_5 (5g, 5w), all_2 (2g, 10w), all_3 (3g, 10w), all_4 (4g, 10w), all_5 (5g, 10w), monotonic (6g, 10w), best_of_family_gbm (6g, 10w), all_gbm (7g, 10w), best_of_family_xglm (8g, 10w), all_xglm (8g, 10w), best_of_family (10g, 10w), best_N (10g, 10w)]}]
# 06:01:20.23: AutoML job created: 2022.05.12 06:01:19.885
# 06:01:20.24: AutoML build started: 2022.05.12 06:01:20.23
# 06:01:20.58: AutoML: starting XGBoost_1_AutoML_1_20220512_60119 model training
#
# █
# 06:01:23.1: New leader: XGBoost_1_AutoML_1_20220512_60119, rmse: 2.028519264057843
# 06:01:23.7: AutoML: starting GLM_1_AutoML_1_20220512_60119 model training
#
#
# 06:01:24.395: AutoML: starting GBM_1_AutoML_1_20220512_60119 model training
#
# ██
# 06:01:28.540: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_1_20220512_60119 model training
# 06:01:28.812: AutoML: starting XGBoost_2_AutoML_1_20220512_60119 model training
#
# █
# 06:01:30.446: AutoML: starting DRF_1_AutoML_1_20220512_60119 model training
#
# ███
# 06:01:37.27: AutoML: starting GBM_2_AutoML_1_20220512_60119 model training
#
# █
# 06:01:41.693: New leader: GBM_2_AutoML_1_20220512_60119, rmse: 1.9082619487407222
# 06:01:41.696: AutoML: starting GBM_3_AutoML_1_20220512_60119 model training
#
# █
# 06:01:45.380: AutoML: starting GBM_4_AutoML_1_20220512_60119 model training
#
# █
# 06:01:50.559: AutoML: starting StackedEnsemble_BestOfFamily_2_AutoML_1_20220512_60119 model training
# 06:01:50.715: AutoML: starting StackedEnsemble_AllModels_1_AutoML_1_20220512_60119 model training
# 06:01:50.873: AutoML: starting XGBoost_3_AutoML_1_20220512_60119 model training
#
#
# 06:01:51.900: AutoML: starting XRT_1_AutoML_1_20220512_60119 model training
#
# ████
# 06:01:58.935: AutoML: starting GBM_5_AutoML_1_20220512_60119 model training
#
# █
# 06:02:02.544: AutoML: starting DeepLearning_1_AutoML_1_20220512_60119 model training
# 06:02:04.527: AutoML: starting StackedEnsemble_BestOfFamily_3_AutoML_1_20220512_60119 model training
# 06:02:04.782: AutoML: starting StackedEnsemble_AllModels_2_AutoML_1_20220512_60119 model training
#
#
# 06:02:04.962: AutoML: starting XGBoost_grid_1_AutoML_1_20220512_60119 hyperparameter search
#
# ██████
# 06:02:52.573: AutoML: starting GBM_grid_1_AutoML_1_20220512_60119 hyperparameter search
#
# ███████████
# 06:04:25.626: AutoML: starting DeepLearning_grid_1_AutoML_1_20220512_60119 hyperparameter search
#
# ██████████████████
# 06:09:02.432: AutoML: starting StackedEnsemble_BestOfFamily_4_AutoML_1_20220512_60119 model training
#
#
# 06:09:02.579: New leader: StackedEnsemble_BestOfFamily_4_AutoML_1_20220512_60119, rmse: 1.8997096521369004
# 06:09:02.581: AutoML: starting StackedEnsemble_AllModels_3_AutoML_1_20220512_60119 model training
# 06:09:03.76: AutoML: starting DeepLearning_grid_2_AutoML_1_20220512_60119 hyperparameter search
#
# █████
# 06:09:58.416: AutoML: starting DeepLearning_grid_3_AutoML_1_20220512_60119 hyperparameter search
#
# █████
# 06:10:55.884: AutoML: starting StackedEnsemble_AllModels_4_AutoML_1_20220512_60119 model training
# 06:10:56.236: Applying learning rate search on best XGBoost: XGBoost_grid_1_AutoML_1_20220512_60119_model_3
# 06:10:56.236: AutoML: starting XGBoost_lr_search_selection_AutoML_1_20220512_60119_select model training
#
# █
# 06:11:00.329: New leader: StackedEnsemble_BestOfFamily_4_AutoML_1_20220512_60119, rmse: 1.8997096521369004
# 06:11:00.347: Retraining best GBM with learning rate annealing: GBM_2_AutoML_1_20220512_60119
# 06:11:00.348: AutoML: starting GBM_lr_annealing_selection_AutoML_1_20220512_60119_select_model model training
#
#
# 06:11:03.185: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 06:11:03.187: AutoML: starting StackedEnsemble_BestOfFamily_5_AutoML_1_20220512_60119 model training
#
#
# 06:11:04.355: AutoML: starting StackedEnsemble_AllModels_5_AutoML_1_20220512_60119 model training
#
# █
# 06:11:10.306: AutoML: starting StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119 model training
#
#
# 06:11:10.877: New leader: StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119, rmse: 1.8979512166370387
# 06:11:10.878: AutoML: starting StackedEnsemble_AllModels_6_AutoML_1_20220512_60119 model training
#
#
# 06:11:12.853: AutoML: starting XGBoost_grid_1_AutoML_1_20220512_60119 hyperparameter search
#
# █| (done) 100%
#
# 06:11:15.804: AutoML: starting GBM_grid_1_AutoML_1_20220512_60119 hyperparameter search
# 06:11:17.501: AutoML: starting StackedEnsemble_Best1000_1_AutoML_1_20220512_60119 model training
# 06:11:17.976: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {StackedEnsemble : [best_of_family_2 (2g, 5w), all_2 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {StackedEnsemble : [best_of_family_3 (3g, 5w), all_3 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_4 (4g, 5w), all_4 (4g, 10w)]}, {DeepLearning : [grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {StackedEnsemble : [all_5 (5g, 10w)]}, {XGBoost : [lr_search (6g, 30w)]}, {GBM : [lr_annealing (6g, 10w)]}, {StackedEnsemble : [best_of_family_gbm (6g, 10w), all_gbm (7g, 10w), best_of_family_xglm (8g, 10w), all_xglm (8g, 10w)]}, {completion : [resume_best_grids (10g, 60w)]}, {StackedEnsemble : [best_N (10g, 10w)]}]
# 06:11:17.977: AutoML build stopped: 2022.05.12 06:11:17.976
# 06:11:17.977: AutoML build done: built 97 models
# 06:11:17.977: AutoML duration:  9 min 57.953 sec
#
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0
# ModelMetricsRegression: deeplearning
# ** Reported on train data. **
#
# MSE: 9.309600903167086
# RMSE: 3.051163860425573
# MAE: 1.3178897499166857
# RMSLE: 0.327706169149253
# Mean Residual Deviance: 9.309600903167086
#
# ModelMetricsRegression: deeplearning
# ** Reported on cross-validation data. **
#
# MSE: 12.805186068066176
# RMSE: 3.5784334656475276
# MAE: 1.5356561755395013
# RMSLE: 0.37276875522254027
# Mean Residual Deviance: 12.805186068066176
#
# **PASS 2 METRICS ::**
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.5274332885837466
# RMSE: 0.7262460248316315
# MAE: 0.5049443854681339
# RMSLE: 0.14431490318093648
# R^2: 0.929789610287499
# Mean Residual Deviance: 0.5274332885837466
# Null degrees of freedom: 562
# Residual degrees of freedom: 559
# Null deviance: 4229.358969357469
# Residual deviance: 296.94494147264936
# AIC: 1247.555172011303
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 3.6022188207340156
# RMSE: 1.8979512166370387
# MAE: 1.2860915864189766
# RMSLE: 0.35518023281401784
# R^2: 0.5204830777508214
# Mean Residual Deviance: 3.6022188207340156
# Null degrees of freedom: 562
# Residual degrees of freedom: 559
# Null deviance: 4238.053851311581
# Residual deviance: 2028.0491960732506
# AIC: 2329.2374354022622

# %%
# Get model ids for all models in the AutoML Leaderboard
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
model_ids
# Out:
# ['StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119',
#  'StackedEnsemble_BestOfFamily_4_AutoML_1_20220512_60119',
#  'StackedEnsemble_AllModels_6_AutoML_1_20220512_60119',
#  'GBM_2_AutoML_1_20220512_60119',
#  'StackedEnsemble_BestOfFamily_2_AutoML_1_20220512_60119',
#  'StackedEnsemble_AllModels_1_AutoML_1_20220512_60119',
#  'StackedEnsemble_AllModels_2_AutoML_1_20220512_60119',
#  'StackedEnsemble_BestOfFamily_3_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_2',
#  'GBM_4_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_31',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_15',
#  'XGBoost_lr_search_selection_AutoML_1_20220512_60119_select_grid_model_3',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_18',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_22',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_34',
#  'StackedEnsemble_AllModels_4_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_28',
#  'XRT_1_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_12',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_3',
#  'StackedEnsemble_AllModels_3_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_32',
#  'StackedEnsemble_Best1000_1_AutoML_1_20220512_60119',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_25',
#  'StackedEnsemble_BestOfFamily_5_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_3',
#  'GBM_3_AutoML_1_20220512_60119',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_9',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_8',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_17',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_9',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_5',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_29',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_21',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_1',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_19',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_30',
#  'StackedEnsemble_AllModels_5_AutoML_1_20220512_60119',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_2',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_7',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_17',
#  'XGBoost_1_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_20',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_15',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_6',
#  'XGBoost_2_AutoML_1_20220512_60119',
#  'XGBoost_3_AutoML_1_20220512_60119',
#  'StackedEnsemble_BestOfFamily_1_AutoML_1_20220512_60119',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_35',
#  'GBM_5_AutoML_1_20220512_60119',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_10',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_5',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_26',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_25',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_36',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_28',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_33',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_22',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_16',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_21',
#  'DRF_1_AutoML_1_20220512_60119',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_18',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_30',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_11',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_13',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_38',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_32',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_14',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_12',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_24',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_23',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_35',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_33',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_23',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_20',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_19',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_24',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_1',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_16',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_8',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_27',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_26',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_34',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_31',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_37',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_7',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_6',
#  'XGBoost_grid_1_AutoML_1_20220512_60119_model_4',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_4',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_29',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_14',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_10',
#  'GBM_1_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_13',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_11',
#  'GLM_1_AutoML_1_20220512_60119',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_27',
#  'GBM_grid_1_AutoML_1_20220512_60119_model_36',
#  'DeepLearning_1_AutoML_1_20220512_60119',
#  'DeepLearning_grid_1_AutoML_1_20220512_60119_model_1',
#  'DeepLearning_grid_1_AutoML_1_20220512_60119_model_4',
#  'DeepLearning_grid_1_AutoML_1_20220512_60119_model_2',
#  'DeepLearning_grid_3_AutoML_1_20220512_60119_model_1',
#  'DeepLearning_grid_3_AutoML_1_20220512_60119_model_2',
#  'DeepLearning_grid_1_AutoML_1_20220512_60119_model_5',
#  'DeepLearning_grid_2_AutoML_1_20220512_60119_model_2',
#  'DeepLearning_grid_2_AutoML_1_20220512_60119_model_1',
#  'DeepLearning_grid_1_AutoML_1_20220512_60119_model_6',
#  'DeepLearning_grid_1_AutoML_1_20220512_60119_model_3']

# %%
pred=aml.leader.predict(test)
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%

# %%
pred.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  1.5113 </td></tr>
# <tr><td style="text-align: right;">  2.5555 </td></tr>
# <tr><td style="text-align: right;">  1.66833</td></tr>
# <tr><td style="text-align: right;">  2.99824</td></tr>
# <tr><td style="text-align: right;">  2.64628</td></tr>
# <tr><td style="text-align: right;">  1.68986</td></tr>
# <tr><td style="text-align: right;">  1.78507</td></tr>
# <tr><td style="text-align: right;">  2.61435</td></tr>
# <tr><td style="text-align: right;">  2.11852</td></tr>
# <tr><td style="text-align: right;">  3.57385</td></tr>
# </tbody>
# </table>

# %%
aml.leader.model_performance(test)
# Out:
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on test data. **
#
# MSE: 3.152414922561927
# RMSE: 1.7755041319472977
# MAE: 1.1888593159134238
# RMSLE: 0.34728239816030787
# R^2: 0.41018100438592986
# Mean Residual Deviance: 3.152414922561927
# Null degrees of freedom: 141
# Residual degrees of freedom: 138
# Null deviance: 765.0570803514427
# Residual deviance: 447.6429190037936
# AIC: 576.018513200635

# %%
#out = h2o.get_model([mid for mid in model_ids if "StackedEnsemble_BestOfFamily_7_AutoML_1_20220418_60039" in mid][0])
#DeepLearning_grid_3_AutoML_1_20220511_93953_model_1
out = h2o.get_model([mid for mid in model_ids if "StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119" in mid][0])

# %%
out.params
# Out:
# {'auc_type': {'actual': 'AUTO', 'default': 'AUTO', 'input': 'AUTO'},
#  'base_models': {'actual': [{'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'GBM_2_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'XGBoost_lr_search_selection_AutoML_1_20220512_60119_select_grid_model_3',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'XRT_1_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'DRF_1_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'GLM_1_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'DeepLearning_1_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'}],
#   'default': [],
#   'input': [{'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'GBM_2_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'XGBoost_lr_search_selection_AutoML_1_20220512_60119_select_grid_model_3',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'XRT_1_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'DRF_1_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'GLM_1_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'DeepLearning_1_AutoML_1_20220512_60119',
#     'type': 'Key<Keyed>'}]},
#  'blending_frame': {'actual': None, 'default': None, 'input': None},
#  'export_checkpoints_dir': {'actual': None, 'default': None, 'input': None},
#  'keep_levelone_frame': {'actual': True, 'default': False, 'input': True},
#  'max_runtime_secs': {'actual': 4.8585, 'default': 0.0, 'input': 4.8585},
#  'metalearner_algorithm': {'actual': 'glm',
#   'default': 'AUTO',
#   'input': 'AUTO'},
#  'metalearner_fold_assignment': {'actual': None,
#   'default': None,
#   'input': None},
#  'metalearner_fold_column': {'actual': None, 'default': None, 'input': None},
#  'metalearner_nfolds': {'actual': 5, 'default': 0, 'input': 5},
#  'metalearner_params': {'actual': '', 'default': '', 'input': ''},
#  'metalearner_transform': {'actual': 'NONE',
#   'default': 'NONE',
#   'input': 'NONE'},
#  'model_id': {'actual': {'URL': '/3/Models/StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119',
#    '__meta': {'schema_name': 'ModelKeyV3',
#     'schema_type': 'Key<Model>',
#     'schema_version': 3},
#    'name': 'StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119',
#    'type': 'Key<Model>'},
#   'default': None,
#   'input': None},
#  'offset_column': {'actual': None, 'default': None, 'input': None},
#  'response_column': {'actual': {'__meta': {'schema_name': 'ColSpecifierV3',
#     'schema_type': 'VecSpecifier',
#     'schema_version': 3},
#    'column_name': 'Product Sulphur',
#    'is_member_of_frames': None},
#   'default': None,
#   'input': {'__meta': {'schema_name': 'ColSpecifierV3',
#     'schema_type': 'VecSpecifier',
#     'schema_version': 3},
#    'column_name': 'Product Sulphur',
#    'is_member_of_frames': None}},
#  'score_training_samples': {'actual': 10000, 'default': 10000, 'input': 10000},
#  'seed': {'actual': 7053024184139601621, 'default': -1, 'input': -1},
#  'training_frame': {'actual': {'URL': '/3/Frames/AutoML_1_20220512_60119_training_py_2_sid_ae58',
#    '__meta': {'schema_name': 'FrameKeyV3',
#     'schema_type': 'Key<Frame>',
#     'schema_version': 3},
#    'name': 'AutoML_1_20220512_60119_training_py_2_sid_ae58',
#    'type': 'Key<Frame>'},
#   'default': None,
#   'input': {'URL': '/3/Frames/AutoML_1_20220512_60119_training_py_2_sid_ae58',
#    '__meta': {'schema_name': 'FrameKeyV3',
#     'schema_type': 'Key<Frame>',
#     'schema_version': 3},
#    'name': 'AutoML_1_20220512_60119_training_py_2_sid_ae58',
#    'type': 'Key<Frame>'}},
#  'validation_frame': {'actual': None, 'default': None, 'input': None},
#  'weights_column': {'actual': None, 'default': None, 'input': None}}

# %%
out
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.5274332885837466
# RMSE: 0.7262460248316315
# MAE: 0.5049443854681339
# RMSLE: 0.14431490318093648
# R^2: 0.929789610287499
# Mean Residual Deviance: 0.5274332885837466
# Null degrees of freedom: 562
# Residual degrees of freedom: 559
# Null deviance: 4229.358969357469
# Residual deviance: 296.94494147264936
# AIC: 1247.555172011303
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 3.6022188207340156
# RMSE: 1.8979512166370387
# MAE: 1.2860915864189766
# RMSLE: 0.35518023281401784
# R^2: 0.5204830777508214
# Mean Residual Deviance: 3.6022188207340156
# Null degrees of freedom: 562
# Residual degrees of freedom: 559
# Null deviance: 4238.053851311581
# Residual deviance: 2028.0491960732506
# AIC: 2329.2374354022622
#
# Cross-Validation Metrics Summary:
#                                  mean          sd  cv_1_valid  cv_2_valid  \
# 0                     mae    1.285378    0.086315    1.270272    1.168627
# 1  mean_residual_deviance    3.569213    0.601089    3.086052    3.142960
# 2                     mse    3.569213    0.601089    3.086052    3.142960
# 3           null_deviance  847.610800  162.091700  687.037800  780.236300
# 4                      r2    0.518764    0.059809    0.512406    0.554289
# 5       residual_deviance  402.924040   76.189514  333.293640  345.725560
# 6                    rmse    1.884186    0.154336    1.756716    1.772839
# 7                   rmsle    0.349962    0.025253    0.357265    0.320238
#
#     cv_3_valid  cv_4_valid  cv_5_valid
# 0
td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_3_AutoML_1_20220512_60119</td><td style="text-align: right;">1.92319</td><td style="text-align: right;">3.69867</td><td style="text-align: right;">1.2977 </td><td style="text-align: right;">0.354896</td><td style="text-align: right;">                 3.69867</td><td style="text-align: right;">               245</td><td style="text-align: right;">                 0.038513</td><td>StackedEnsemble</td><td style="text-align: right;">  15.7688</td></tr>
# <tr><td>GBM_grid_1_AutoML_1_20220512_60119_model_2            </td><td style="text-align: right;">1.92482</td><td style="text-align: right;">3.70492</td><td style="text-align: right;">1.307  </td><td style="text-align: right;">0.352756</td><td style="text-align: right;">                 3.70492</td><td style="text-align: right;">               242</td><td style="text-align: right;">                 0.018768</td><td>GBM            </td><td style="text-align: right;">  16.1638</td></tr>
# <tr><td>GBM_4_AutoML_1_20220512_60119                         </td><td style="text-align: right;">1.9253 </td><td style="text-align: right;">3.70677</td><td style="text-align: right;">1.3107 </td><td style="text-align: right;">0.360342</td><td style="text-align: right;">                 3.70677</td><td style="text-align: right;">               866</td><td style="text-align: right;">                 0.024458</td><td>GBM            </td><td style="text-align: right;">  16.9462</td></tr>
# </tbody>
# </table>
# # SHAP Explanation
# > SHAP explanation shows contribution of features for a given instance. The sum of the feature contributions and the bias term is equal to the raw prediction of the model, i.e., prediction before applying inverse link function. H2O implements TreeSHAP which when the features are correlated, can increase contribution of a feature that had no influence on the prediction.
# /usr/local/lib/python3.7/dist-packages/h2o/explanation/_explain.py:3175: UserWarning: No model with variable importance. Selecting all features to explain.
#   warnings.warn("No model with variable importance. Selecting all features to explain.")
# # Individual Conditional Expectation
# > Individual conditional expectations (ICE) plot gives a graphical depiction of the marginal effect of a variable on the response for a given row. ICE plot is similar to partial dependence plot (PDP), PDP shows the average effect of a feature while ICE plot shows the effect for a single instance.
# # Individual Conditional Expectation
# > Individual conditional expectations (ICE) plot gives a graphical depiction of the marginal effect of a variable on the response for a given row. ICE plot is similar to partial dependence plot (PDP), PDP shows the average effect of a feature while ICE plot shows the effect for a single instance.

# %%
ra_plot = out.residual_analysis_plot(test)

# %%
#ra_plot = aml.varimp_plot()
out.varimp_plot()
# Out:
# ---------------------------------------------------------------------------
# H2OValueError                             Traceback (most recent call last)
# <ipython-input-30-6abf267d39f4> in <module>()
#       1 #ra_plot = aml.varimp_plot()
# ----> 2 out.varimp_plot()
#
# /usr/local/lib/python3.7/dist-packages/h2o/model/model_base.py in varimp_plot(self, num_of_features, server, save_plot_path)
#    1581         if has_extension(self, 'VariableImportance'):
#    1582             return self._varimp_plot(num_of_features=num_of_features, server=server, save_plot_path=save_plot_path)
# -> 1583         raise H2OValueError("Variable importance plot is not available for this type of model (%s)." % self.algo)
#    1584
#    1585     def std_coef_plot(self, num_of_features=None, server=False, save_plot_path=None):
#
# H2OValueError: Variable importance plot is not available for this type of model (stackedensemble).

# %%
# save the model
model_path_4 = aml.leader.download_mojo(path = "./")

# %%
print (model_path_4)
# Out:
# /content/StackedEnsemble_BestOfFamily_6_AutoML_1_20220512_60119.zip

# %%
imported_model = h2o.import_mojo(model_path_4)
# Out:
# generic Model Build progress: |██████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OGenericEstimator :  Import MOJO Model
# Model Key:  Generic_model_python_1652335172543_35
#
# No model summary for this model
#
# ModelMetricsRegressionGeneric: generic
# ** Reported on train data. **
#
# MSE: 0.5274332885837466
# RMSE: 0.7262460248316315
# MAE: 0.5049443854681339
# RMSLE: 0.14431490318093648
# Mean Residual Deviance: 0.5274332885837466
#
# ModelMetricsRegressionGeneric: generic
# ** Reported on cross-validation data. **
#
# MSE: 3.6022188207340156
# RMSE: 1.8979512166370387
# MAE: 1.2860915864189766
# RMSLE: 0.35518023281401784
# Mean Residual Deviance: 3.6022188207340156
#
# Cross-Validation Metrics Summary:
#                                  mean          sd  cv_1_valid  cv_2_valid  \
# 0                     mae    1.285378    0.086315    1.270272    1.168627
# 1  mean_residual_deviance    3.569213    0.601089    3.086052    3.142960
# 2                     mse    3.569213    0.601089    3.086052    3.142960
# 3           null_deviance  847.610800  162.091700  687.037800  780.236300
# 4                      r2    0.518764    0.059809    0.512406    0.554289
# 5       residual_deviance  402.924040   76.189514  333.293640  345.725560
# 6                    rmse    1.884186    0.154336    1.756716    1.772839
# 7                   rmsle    0.349962    0.025253    0.357265    0.320238
#
#     cv_3_valid  cv_4_valid  cv_5_valid
# 0     1.360277    1.379851    1.247863
# 1     4.550345    3.713499    3.353210
# 2     4.550345    3.713499    3.353210
# 3  1073.623500  739.747500  957.408700
# 4     0.512524    0.427601    0.587002
# 5   523.289730  423.338930  388.972400
# 6     2.133154    1.927044    1.831177
# 7     0.349053    0.387521    0.335735

# %%
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-48acbb46-7a73-4445-b497-339f7266f473" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48acbb46-7a73-4445-b497-339f7266f473">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KHDS_TestData_12Apr_rev_1.csv to KHDS_TestData_12Apr_rev_1.csv

# %%
for fn in uploaded1.keys():
  print('User uploaded1 file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded1[fn])))
# Out:
# User uploaded1 file "KHDS_TestData_12Apr_rev_1.csv" with length 21413 bytes

# %%
new_observations = h2o.import_file(path='KHDS_TestData_12Apr_rev_1.csv')
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
predictions = imported_model.predict(new_observations)
# Out:
# generic prediction progress: |███████████████████████████████████████████████████| (done) 100%

# %%
predictions.head(52)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 15.6239 </td></tr>
# <tr><td style="text-align: right;"> 16.833  </td></tr>
# <tr><td style="text-align: right;"> 16.4866 </td></tr>
# <tr><td style="text-align: right;">  4.04345</td></tr>
# <tr><td style="text-align: right;">  4.21162</td></tr>
# <tr><td style="text-align: right;">  4.39423</td></tr>
# <tr><td style="text-align: right;">  4.73168</td></tr>
# <tr><td style="text-align: right;">  3.66057</td></tr>
# <tr><td style="text-align: right;">  3.75074</td></tr>
# <tr><td style="text-align: right;">  3.90304</td></tr>
# <tr><td style="text-align: right;">  4.06079</td></tr>
# <tr><td style="text-align: right;">  3.28366</td></tr>
# <tr><td style="text-align: right;">  4.41751</td></tr>
# <tr><td style="text-align: right;">  4.63258</td></tr>
# <tr><td style="text-align: right;">  4.79945</td></tr>
# <tr><td style="text-align: right;">  4.56486</td></tr>
# <tr><td style="text-align: right;">  7.41656</td></tr>
# <tr><td style="text-align: right;">  4.47071</td></tr>
# <tr><td style="text-align: right;">  4.95895</td></tr>
# <tr><td style="text-align: right;"> 16.4261 </td></tr>
# <tr><td style="text-align: right;"> 14.7343 </td></tr>
# <tr><td style="text-align: right;"> 15.8006 </td></tr>
# <tr><td style="text-align: right;"> 15.4728 </td></tr>
# <tr><td style="text-align: right;"> 15.7957 </td></tr>
# <tr><td style="text-align: right;"> 16.5814 </td></tr>
# <tr><td style="text-align: right;"> 13.8294 </td></tr>
# <tr><td style="text-align: right;">  4.20826</td></tr>
# <tr><td style="text-align: right;">  4.24661</td></tr>
# <tr><td style="text-align: right;">  4.12704</td></tr>
# <tr><td style="text-align: right;">  4.32739</td></tr>
# <tr><td style="text-align: right;">  4.09036</td></tr>
# <tr><td style="text-align: right;">  4.81164</td></tr>
# <tr><td style="text-align: right;">  3.20783</td></tr>
# <tr><td style="text-align: right;">  2.91749</td></tr>
# <tr><td style="text-align: right;">  4.14683</td></tr>
# <tr><td style="text-align: right;">  3.58859</td></tr>
# <tr><td style="text-align: right;">  3.57864</td></tr>
# <tr><td style="text-align: right;">  4.1189 </td></tr>
# <tr><td style="text-align: right;">  3.58834</td></tr>
# <tr><td style="text-align: right;">  6.28965</td></tr>
# <tr><td style="text-align: right;">  4.52955</td></tr>
# <tr><td style="text-align: right;">  4.0226 </td></tr>
# <tr><td style="text-align: right;">  3.04736</td></tr>
# <tr><td style="text-align: right;">  2.89112</td></tr>
# <tr><td style="text-align: right;"> 40.883  </td></tr>
# <tr><td style="text-align: right;"> 40.8202 </td></tr>
# <tr><td style="text-align: right;"> 40.3068 </td></tr>
# </tbody>
# </table>
# <bound method H2OFrame.describe of >

# %%
# Explain first row with all AutoML models
aml.explain_row(test, row_index=0)

# Explain first row with a single H2O model (e.g. leader model from AutoML)
aml.leader.explain_row(test, row_index=0)
# Out:
# # Leaderboard
# > Leaderboard shows models with their metrics and their predictions for a given row. When provided with H2OAutoML object, the leaderboard shows 5-fold cross-validated metrics by default (depending on the H2OAutoML settings), otherwise it shows metrics computed on the frame. At most 20 models are shown by default.
# <table>
# <thead>
# <tr><th>model_id                                              </th><th style="text-align: right;">   rmse</th><th style="text-align: right;">    mse</th><th style="text-align: right;">    mae</th><th style="text-align: right;">     rmsle</th><th style="text-align: right;">  mean_residual_deviance</th><th style="text-align: right;">  training_time_ms</th><th style="text-align: right;">  predict_time_per_row_ms</th><th>algo           </th><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td>DeepLearning_grid_3_AutoML_1_20220511_93953_model_1   </td><td style="text-align: right;">3.57843</td><td style="text-align: right;">12.8052</td><td style="text-align: right;">1.53566</td><td style="text-align: right;">  0.372769</td><td style="text-align: right;">                 12.8052</td><td style="text-align: right;">             10502</td><td style="text-align: right;">                 0.100857</td><td>DeepLearning   </td><td style="text-align: right;"> 1.5113  </td></tr>
# <tr><td>StackedEnsemble_AllModels_6_AutoML_1_20220511_93953   </td><td style="text-align: right;">3.6916 </td><td style="text-align: right;">13.6279</td><td style="text-align: right;">1.59939</td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 13.6279</td><td style="text-align: right;">              1706</td><td style="text-align: right;">                 0.248717</td><td>StackedEnsemble</td><td style="text-align: right;"> 0.588214</td></tr>
# <tr><td>DeepLearning_grid_2_AutoML_1_20220511_93953_model_1   </td><td style="text-align: right;">3.69835</td><td style="text-align: right;">13.6778</td><td style="text-align: right;">1.6199 </td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 13.6778</td><td style="text-align: right;">              9905</td><td style="text-align: right;">                 0.013593</td><td>DeepLearning   </td><td style="text-align: right;"> 1.3602  </td></tr>
# <tr><td>DeepLearning_grid_1_AutoML
ICE) plot gives a graphical depiction of the marginal effect of a variable on the response for a given row. ICE plot is similar to partial dependence plot (PDP), PDP shows the average effect of a feature while ICE plot shows the effect for a single instance.
# # Individual Conditional Expectation
# > Individual conditional expectations (ICE) plot gives a graphical depiction of the marginal effect of a variable on the response for a given row. ICE plot is similar to partial dependence plot (PDP), PDP shows the average effect of a feature while ICE plot shows the effect for a single instance.

# %%
out.default_params
# Out:
# {'activation': 'Rectifier',
#  'adaptive_rate': True,
#  'auc_type': 'AUTO',
#  'autoencoder': False,
#  'average_activation': 0.0,
#  'balance_classes': False,
#  'categorical_encoding': 'AUTO',
#  'checkpoint': None,
#  'class_sampling_factors': None,
#  'classification_stop': 0.0,
#  'col_major': False,
#  'diagnostics': True,
#  'distribution': 'AUTO',
#  'elastic_averaging': False,
#  'elastic_averaging_moving_rate': 0.9,
#  'elastic_averaging_regularization': 0.001,
#  'epochs': 10.0,
#  'epsilon': 1e-08,
#  'export_checkpoints_dir': None,
#  'export_weights_and_biases': False,
#  'fast_mode': True,
#  'fold_assignment': 'AUTO',
#  'fold_column': None,
#  'force_load_balance': True,
#  'hidden': [200, 200],
#  'hidden_dropout_ratios': None,
#  'huber_alpha': 0.9,
#  'ignore_const_cols': True,
#  'ignored_columns': None,
#  'initial_biases': None,
#  'initial_weight_distribution': 'UniformAdaptive',
#  'initial_weight_scale': 1.0,
#  'initial_weights': None,
#  'input_dropout_ratio': 0.0,
#  'keep_cross_validation_fold_assignment': False,
#  'keep_cross_validation_models': True,
#  'keep_cross_validation_predictions': False,
#  'l1': 0.0,
#  'l2': 0.0,
#  'loss': 'Automatic',
#  'max_after_balance_size': 5.0,
#  'max_categorical_features': 2147483647,
#  'max_confusion_matrix_size': 20,
#  'max_runtime_secs': 0.0,
#  'max_w2': 3.4028235e+38,
#  'mini_batch_size': 1,
#  'missing_values_handling': 'MeanImputation',
#  'model_id': None,
#  'momentum_ramp': 1000000.0,
#  'momentum_stable': 0.0,
#  'momentum_start': 0.0,
#  'nesterov_accelerated_gradient': True,
#  'nfolds': 0,
#  'offset_column': None,
#  'overwrite_with_best_model': True,
#  'pretrained_autoencoder': None,
#  'quantile_alpha': 0.5,
#  'quiet_mode': False,
#  'rate': 0.005,
#  'rate_annealing': 1e-06,
#  'rate_decay': 1.0,
#  'regression_stop': 1e-06,
#  'replicate_training_data': True,
#  'reproducible': False,
#  'response_column': None,
#  'rho': 0.99,
#  'score_duty_cycle': 0.1,
#  'score_each_iteration': False,
#  'score_interval': 5.0,
#  'score_training_samples': 10000,
#  'score_validation_samples': 0,
#  'score_validation_sampling': 'Uniform',
#  'seed': -1,
#  'shuffle_training_data': False,
#  'single_node_mode': False,
#  'sparse': False,
#  'sparsity_beta': 0.0,
#  'standardize': True,
#  'stopping_metric': 'AUTO',
#  'stopping_rounds': 5,
#  'stopping_tolerance': 0.0,
#  'target_ratio_comm_to_comp': 0.05,
#  'train_samples_per_iteration': -2,
#  'training_frame': None,
#  'tweedie_power': 1.5,
#  'use_all_factor_levels': True,
#  'validation_frame': None,
#  'variable_importances': True,
#  'weights_column': None}

# %%
out.model_performance
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DeepLearning_grid_3_AutoML_1_20220511_93953_model_1
#
#
# Status of Neuron Layers: predicting Product Sulphur, regression, gaussian distribution, Quadratic loss, 23,701 weights/biases, 292.6 KB, 46,965 training samples, mini-batch size 1
#      layer  units              type dropout   l1   l2 mean_rate  rate_rms  \
# 0        1     33             Input     5.0
# 1        2    100  RectifierDropout    10.0  0.0  0.0  0.006323  0.008727
# 2        3    100  RectifierDropout    10.0  0.0  0.0   0.00545  0.004544
# 3        4    100  RectifierDropout    10.0  0.0  0.0  0.006503  0.011616
# 4        5      1            Linear          0.0  0.0   0.00046  0.000413
#
#   momentum mean_weight weight_rms mean_bias  bias_rms
# 0
# 1      0.0    0.006528    0.13228  0.476229  0.054664
# 2      0.0   -0.011503   0.104786  0.991284  0.032594
# 3      0.0   -0.010921   0.102213  0.986081  0.024685
# 4      0.0   -0.000889    0.10739  0.107078       0.0
# ModelMetricsRegression: deeplearning
# ** Reported on train data. **
#
# MSE: 9.309600903167086
# RMSE: 3.051163860425573
# MAE: 1.3178897499166857
# RMSLE: 0.327706169149253
# Mean Residual Deviance: 9.309600903167086
#
# ModelMetricsRegression: deeplearning
# ** Reported on cross-validation data. **
#
# MSE: 12.805186068066176
# RMSE: 3.5784334656475276
# MAE: 1.5356561755395013
# RMSLE: 0.37276875522254027
# Mean Residual Deviance: 12.805186068066176
#
# Cross-Validation Metrics Summary:
#                                 mean         sd  cv_1_valid  cv_2_valid  \
# 0                     mae   1.512831   0.202720    1.378209    1.245958
# 1  mean_residual_deviance  13.339622  11.946567    5.488487    3.646299
# 2                     mse  13.339622  11.946567    5.488487    3.646299
# 3                      r2   0.425399   0.161918    0.561918    0.495553
# 4       residual_deviance  13.339622  11.946567    5.488487    3.646299
# 5                    rmse   3.378013   1.552679    2.342752    1.909528
# 6                   rmsle   0.378259   0.037738    0.354749    0.378849
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    1.540278    1.746374    1.653337
# 1   17.552038    7.582580   32.428703
# 2   17.552038    7.582580   32.428703
# 3    0.148003    0.430256    0.491265
# 4   17.552038    7.582580   32.428703
# 5    4.189516    2.753649    5.694621
# 6    0.424169    0.403989    0.329538
# Scoring History:
#                timestamp    duration training_speed     epochs  iterations  \
# 0    2022-05-11 09:49:09   0.000 sec           None   0.000000           0
# 1    2022-05-11 09:49:10  50.544 sec   3123 obs/sec   7.507937           1
# 2    2022-05-11 09:49:16  56.406 sec   4143 obs/sec  52.657848           7
# 3    2022-05-11 09:49:19  59.656 sec   4499 obs/sec  82.830688          11
#
#    samples  training_rmse  training_deviance  training_mae  training_r2
# 0      0.0            NaN                NaN           NaN          NaN
# 1   4257.0       4.534217          20.559126      2.053815     0.126172
# 2  29857.0       3.387425          11.474648      1.377257     0.512291
# 3  46965.0       3.051164           9.309601      1.317890     0.604312
# Variable Importances:
#                                      variable  relative_importance  \
# 0         T3 : Reactor inlet temperature DEGC             1.000000
# 1         T1 : Reactor inlet temperature DEGC             0.949103
# 2         T4 : Reactor inlet temperature DEGC             0.899897
# 3   T2 : REACTOR FEED INLET Pressure KGperCM2             0.887644
# 4               T3 : REACTOR OUTLET Temp DEGC             0.856817
# 5               T4 : REACTOR OUTLET Temp DEGC             0.839379
# 6               T1 : REACTOR OUTLET Temp DEGC             0.837825
# 7         T2 : Reactor inlet temperature DEGC             0.832542
# 8       T2 : Hydrogen make-up flow NM3perHour             0.822059
# 9               T2 : REACTOR OUTLET Temp DEGC             0.813328
# 10  T3 : REACTOR FEED INLET Pressure KGperCM2             0.781455
# 11      T4 : Cold separator pressure KGperCM2             0.777041
# 12     T4 : FRESH FEED FLOW TO KHDS KGPerHour             0.762801
# 13      T1 : Cold separator pressure KGperCM2             0.758997
# 14     T1 : FRESH FEED FLOW TO KHDS KGPerHour             0.758551
# 15      T3 : Hydrogen make-up flow NM3perHour             0.747444
# 16      T4 : Recycle hydrogen flow NM3perHour             0.745980
# 17      T3 : Cold separator pressure KGperCM2             0.744364
# 18      T4 : Hydrogen make-up flow NM3perHour             0.742804
# 19            T1 : KERO FEED DENSITY KGperCM2             0.742692
#
#     scaled_importance  percentage
# 0            1.000000    0.039276
# 1            0.949103    0.037277
# 2            0.899897    0.035344
# 3            0.887644    0.034863
# 4            0.856817    0.033652
# 5            0.839379    0.032967
# 6            0.837825    0.032906
# 7            0.832542    0.032699
# 8            0.822059    0.032287
# 9            0.813328    0.031944
# 10           0.781455    0.030692
# 11           0.777041    0.030519
# 12           0.762801    0.029960
# 13           0.758997    0.029810
# 14           0.758551    0.029793
# 15           0.747444    0.029357
# 16           0.745980    0.029299
# 17           0.744364    0.029236
# 18           0.742804    0.029174
# 19           0.742692    0.029170
# See the whole table with table.as_data_frame()
# <bound method ModelBase.model_performance of >

# %%
out.epochs
# Out:
# 10.0

# %%
out.explain
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DeepLearning_grid_3_AutoML_1_20220511_93953_model_1
#
#
# Status of Neuron Layers: predicting Product Sulphur, regression, gaussian distribution, Quadratic loss, 23,701 weights/biases, 292.6 KB, 46,965 training samples, mini-batch size 1
#      layer  units              type dropout   l1   l2 mean_rate  rate_rms  \
# 0        1     33             Input     5.0
# 1        2    100  RectifierDropout    10.0  0.0  0.0  0.006323  0.008727
# 2        3    100  RectifierDropout    10.0  0.0  0.0   0.00545  0.004544
# 3        4    100  RectifierDropout    10.0  0.0  0.0  0.006503  0.011616
# 4        5      1            Linear          0.0  0.0   0.00046  0.000413
#
#   momentum mean_weight weight_rms mean_bias  bias_rms
# 0
# 1      0.0    0.006528    0.13228  0.476229  0.054664
# 2      0.0   -0.011503   0.104786  0.991284  0.032594
# 3      0.0   -0.010921   0.102213  0.986081  0.024685
# 4      0.0   -0.000889    0.10739  0.107078       0.0
# ModelMetricsRegression: deeplearning
# ** Reported on train data. **
#
# MSE: 9.309600903167086
# RMSE: 3.051163860425573
# MAE: 1.3178897499166857
# RMSLE: 0.327706169149253
# Mean Residual Deviance: 9.309600903167086
#
# ModelMetricsRegression: deeplearning
# ** Reported on cross-validation data. **
#
# MSE: 12.805186068066176
# RMSE: 3.5784334656475276
# MAE: 1.5356561755395013
# RMSLE: 0.37276875522254027
# Mean Residual Deviance: 12.805186068066176
#
# Cross-Validation Metrics Summary:
#                                 mean         sd  cv_1_valid  cv_2_valid  \
# 0                     mae   1.512831   0.202720    1.378209    1.245958
# 1  mean_residual_deviance  13.339622  11.946567    5.488487    3.646299
# 2                     mse  13.339622  11.946567    5.488487    3.646299
# 3                      r2   0.425399   0.161918    0.561918    0.495553
# 4       residual_deviance  13.339622  11.946567    5.488487    3.646299
# 5                    rmse   3.378013   1.552679    2.342752    1.909528
# 6                   rmsle   0.378259   0.037738    0.354749    0.378849
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    1.540278    1.746374    1.653337
# 1   17.552038    7.582580   32.428703
# 2   17.552038    7.582580   32.428703
# 3    0.148003    0.430256    0.491265
# 4   17.552038    7.582580   32.428703
# 5    4.189516    2.753649    5.694621
# 6    0.424169    0.403989    0.329538
# Scoring History:
#                timestamp    duration training_speed     epochs  iterations  \
# 0    2022-05-11 09:49:09   0.000 sec           None   0.000000           0
# 1    2022-05-11 09:49:10  50.544 sec   3123 obs/sec   7.507937           1
# 2    2022-05-11 09:49:16  56.406 sec   4143 obs/sec  52.657848           7
# 3    2022-05-11 09:49:19  59.656 sec   4499 obs/sec  82.830688          11
#
#    samples  training_rmse  training_deviance  training_mae  training_r2
# 0      0.0            NaN                NaN           NaN          NaN
# 1   4257.0       4.534217          20.559126      2.053815     0.126172
# 2  29857.0       3.387425          11.474648      1.377257     0.512291
# 3  46965.0       3.051164           9.309601      1.317890     0.604312
# Variable Importances:
#                                      variable  relative_importance  \
# 0         T3 : Reactor inlet temperature DEGC             1.000000
# 1         T1 : Reactor inlet temperature DEGC             0.949103
# 2         T4 : Reactor inlet temperature DEGC             0.899897
# 3   T2 : REACTOR FEED INLET Pressure KGperCM2             0.887644
# 4               T3 : REACTOR OUTLET Temp DEGC             0.856817
# 5               T4 : REACTOR OUTLET Temp DEGC             0.839379
# 6               T1 : REACTOR OUTLET Temp DEGC             0.837825
# 7         T2 : Reactor inlet temperature DEGC             0.832542
# 8       T2 : Hydrogen make-up flow NM3perHour             0.822059
# 9               T2 : REACTOR OUTLET Temp DEGC             0.813328
# 10  T3 : REACTOR FEED INLET Pressure KGperCM2             0.781455
# 11      T4 : Cold separator pressure KGperCM2             0.777041
# 12     T4 : FRESH FEED FLOW TO KHDS KGPerHour             0.762801
# 13      T1 : Cold separator pressure KGperCM2             0.758997
# 14     T1 : FRESH FEED FLOW TO KHDS KGPerHour             0.758551
# 15      T3 : Hydrogen make-up flow NM3perHour             0.747444
# 16      T4 : Recycle hydrogen flow NM3perHour             0.745980
# 17      T3 : Cold separator pressure KGperCM2             0.744364
# 18      T4 : Hydrogen make-up flow NM3perHour             0.742804
# 19            T1 : KERO FEED DENSITY KGperCM2             0.742692
#
#     scaled_importance  percentage
# 0            1.000000    0.039276
# 1            0.949103    0.037277
# 2            0.899897    0.035344
# 3            0.887644    0.034863
# 4            0.856817    0.033652
# 5            0.839379    0.032967
# 6            0.837825    0.032906
# 7            0.832542    0.032699
# 8            0.822059    0.032287
# 9            0.813328    0.031944
# 10           0.781455    0.030692
# 11           0.777041    0.030519
# 12           0.762801    0.029960
# 13           0.758997    0.029810
# 14           0.758551    0.029793
# 15           0.747444    0.029357
# 16           0.745980    0.029299
# 17           0.744364    0.029236
# 18           0.742804    0.029174
# 19           0.742692    0.029170
# See the whole table with table.as_data_frame()
# <bound method explain of >

# %%
out.ice_plot
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DeepLearning_grid_3_AutoML_1_20220511_93953_model_1
#
#
# Status of Neuron Layers: predicting Product Sulphur, regression, gaussian distribution, Quadratic loss, 23,701 weights/biases, 292.6 KB, 46,965 training samples, mini-batch size 1
#      layer  units              type dropout   l1   l2 mean_rate  rate_rms  \
# 0        1     33             Input     5.0
# 1        2    100  RectifierDropout    10.0  0.0  0.0  0.006323  0.008727
# 2        3    100  RectifierDropout    10.0  0.0  0.0   0.00545  0.004544
# 3        4    100  RectifierDropout    10.0  0.0  0.0  0.006503  0.011616
# 4        5      1            Linear          0.0  0.0   0.00046  0.000413
#
#   momentum mean_weight weight_rms mean_bias  bias_rms
# 0
# 1      0.0    0.006528    0.13228  0.476229  0.054664
# 2      0.0   -0.011503   0.104786  0.991284  0.032594
# 3      0.0   -0.010921   0.102213  0.986081  0.024685
# 4      0.0   -0.000889    0.10739  0.107078       0.0
# ModelMetricsRegression: deeplearning
# ** Reported on train data. **
#
# MSE: 9.309600903167086
# RMSE: 3.051163860425573
# MAE: 1.3178897499166857
# RMSLE: 0.327706169149253
# Mean Residual Deviance: 9.309600903167086
#
# ModelMetricsRegression: deeplearning
# ** Reported on cross-validation data. **
#
# MSE: 12.805186068066176
# RMSE: 3.5784334656475276
# MAE: 1.5356561755395013
# RMSLE: 0.37276875522254027
# Mean Residual Deviance: 12.805186068066176
#
# Cross-Validation Metrics Summary:
#                                 mean         sd  cv_1_valid  cv_2_valid  \
# 0                     mae   1.512831   0.202720    1.378209    1.245958
# 1  mean_residual_deviance  13.339622  11.946567    5.488487    3.646299
# 2                     mse  13.339622  11.946567    5.488487    3.646299
# 3                      r2   0.425399   0.161918    0.561918    0.495553
# 4       residual_deviance  13.339622  11.946567    5.488487    3.646299
# 5                    rmse   3.378013   1.552679    2.342752    1.909528
# 6                   rmsle   0.378259   0.037738    0.354749    0.378849
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    1.540278    1.746374    1.653337
# 1   17.552038    7.582580   32.428703
# 2   17.552038    7.582580   32.428703
# 3    0.148003    0.430256    0.491265
# 4   17.552038    7.582580   32.428703
# 5    4.189516    2.753649    5.694621
# 6    0.424169    0.403989    0.329538
# Scoring History:
#                timestamp    duration training_speed     epochs  iterations  \
# 0    2022-05-11 09:49:09   0.000 sec           None   0.000000           0
# 1    2022-05-11 09:49:10  50.544 sec   3123 obs/sec   7.507937           1
# 2    2022-05-11 09:49:16  56.406 sec   4143 obs/sec  52.657848           7
# 3    2022-05-11 09:49:19  59.656 sec   4499 obs/sec  82.830688          11
#
#    samples  training_rmse  training_deviance  training_mae  training_r2
# 0      0.0            NaN                NaN           NaN          NaN
# 1   4257.0       4.534217          20.559126      2.053815     0.126172
# 2  29857.0       3.387425          11.474648      1.377257     0.512291
# 3  46965.0       3.051164           9.309601      1.317890     0.604312
# Variable Importances:
#                                      variable  relative_importance  \
# 0         T3 : Reactor inlet temperature DEGC             1.000000
# 1         T1 : Reactor inlet temperature DEGC             0.949103
# 2         T4 : Reactor inlet temperature DEGC             0.899897
# 3   T2 : REACTOR FEED INLET Pressure KGperCM2             0.887644
# 4               T3 : REACTOR OUTLET Temp DEGC             0.856817
# 5               T4 : REACTOR OUTLET Temp DEGC             0.839379
# 6               T1 : REACTOR OUTLET Temp DEGC             0.837825
# 7         T2 : Reactor inlet temperature DEGC             0.832542
# 8       T2 : Hydrogen make-up flow NM3perHour             0.822059
# 9               T2 : REACTOR OUTLET Temp DEGC             0.813328
# 10  T3 : REACTOR FEED INLET Pressure KGperCM2             0.781455
# 11      T4 : Cold separator pressure KGperCM2             0.777041
# 12     T4 : FRESH FEED FLOW TO KHDS KGPerHour             0.762801
# 13      T1 : Cold separator pressure KGperCM2             0.758997
# 14     T1 : FRESH FEED FLOW TO KHDS KGPerHour             0.758551
# 15      T3 : Hydrogen make-up flow NM3perHour             0.747444
# 16      T4 : Recycle hydrogen flow NM3perHour             0.745980
# 17      T3 : Cold separator pressure KGperCM2             0.744364
# 18      T4 : Hydrogen make-up flow NM3perHour             0.742804
# 19            T1 : KERO FEED DENSITY KGperCM2             0.742692
#
#     scaled_importance  percentage
# 0            1.000000    0.039276
# 1            0.949103    0.037277
# 2            0.899897    0.035344
# 3            0.887644    0.034863
# 4            0.856817    0.033652
# 5            0.839379    0.032967
# 6            0.837825    0.032906
# 7            0.832542    0.032699
# 8            0.822059    0.032287
# 9            0.813328    0.031944
# 10           0.781455    0.030692
# 11           0.777041    0.030519
# 12           0.762801    0.029960
# 13           0.758997    0.029810
# 14           0.758551    0.029793
# 15           0.747444    0.029357
# 16           0.745980    0.029299
# 17           0.744364    0.029236
# 18           0.742804    0.029174
# 19           0.742692    0.029170
# See the whole table with table.as_data_frame()
# <bound method ice_plot of >

# %%
out.learning_curve_plot
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DeepLearning_grid_3_AutoML_1_20220511_93953_model_1
#
#
# Status of Neuron Layers: predicting Product Sulphur, regression, gaussian distribution, Quadratic loss, 23,701 weights/biases, 292.6 KB, 46,965 training samples, mini-batch size 1
#      layer  units              type dropout   l1   l2 mean_rate  rate_rms  \
# 0        1     33             Input     5.0
# 1        2    100  RectifierDropout    10.0  0.0  0.0  0.006323  0.008727
# 2        3    100  RectifierDropout    10.0  0.0  0.0   0.00545  0.004544
# 3        4    100  RectifierDropout    10.0  0.0  0.0  0.006503  0.011616
# 4        5      1            Linear          0.0  0.0   0.00046  0.000413
#
#   momentum mean_weight weight_rms mean_bias  bias_rms
# 0
# 1      0.0    0.006528    0.13228  0.476229  0.054664
# 2      0.0   -0.011503   0.104786  0.991284  0.032594
# 3      0.0   -0.010921   0.102213  0.986081  0.024685
# 4      0.0   -0.000889    0.10739  0.107078       0.0
# ModelMetricsRegression: deeplearning
# ** Reported on train data. **
#
# MSE: 9.309600903167086
# RMSE: 3.051163860425573
# MAE: 1.3178897499166857
# RMSLE: 0.327706169149253
# Mean Residual Deviance: 9.309600903167086
#
# ModelMetricsRegression: deeplearning
# ** Reported on cross-validation data. **
#
# MSE: 12.805186068066176
# RMSE: 3.5784334656475276
# MAE: 1.5356561755395013
# RMSLE: 0.37276875522254027
# Mean Residual Deviance: 12.805186068066176
#
# Cross-Validation Metrics Summary:
#                                 mean         sd  cv_1_valid  cv_2_valid  \
# 0                     mae   1.512831   0.202720    1.378209    1.245958
# 1  mean_residual_deviance  13.339622  11.946567    5.488487    3.646299
# 2                     mse  13.339622  11.946567    5.488487    3.646299
# 3                      r2   0.425399   0.161918    0.561918    0.495553
# 4       residual_deviance  13.339622  11.946567    5.488487    3.646299
# 5                    rmse   3.378013   1.552679    2.342752    1.909528
# 6                   rmsle   0.378259   0.037738    0.354749    0.378849
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    1.540278    1.746374    1.653337
# 1   17.552038    7.582580   32.428703
# 2   17.552038    7.582580   32.428703
# 3    0.148003    0.430256    0.491265
# 4   17.552038    7.582580   32.428703
# 5    4.189516    2.753649    5.694621
# 6    0.424169    0.403989    0.329538
# Scoring History:
#                timestamp    duration training_speed     epochs  iterations  \
# 0    2022-05-11 09:49:09   0.000 sec           None   0.000000           0
# 1    2022-05-11 09:49:10  50.544 sec   3123 obs/sec   7.507937           1
# 2    2022-05-11 09:49:16  56.406 sec   4143 obs/sec  52.657848           7
# 3    2022-05-11 09:49:19  59.656 sec   4499 obs/sec  82.830688          11
#
#    samples  training_rmse  training_deviance  training_mae  training_r2
# 0      0.0            NaN                NaN           NaN          NaN
# 1   4257.0       4.534217          20.559126      2.053815     0.126172
# 2  29857.0       3.387425          11.474648      1.377257     0.512291
# 3  46965.0       3.051164           9.309601      1.317890     0.604312
# Variable Importances:
#                                      variable  relative_importance  \
# 0         T3 : Reactor inlet temperature DEGC             1.000000
# 1         T1 : Reactor inlet temperature DEGC             0.949103
# 2         T4 : Reactor inlet temperature DEGC             0.899897
# 3   T2 : REACTOR FEED INLET Pressure KGperCM2             0.887644
# 4               T3 : REACTOR OUTLET Temp DEGC             0.856817
# 5               T4 : REACTOR OUTLET Temp DEGC             0.839379
# 6               T1 : REACTOR OUTLET Temp DEGC             0.837825
# 7         T2 : Reactor inlet temperature DEGC             0.832542
# 8       T2 : Hydrogen make-up flow NM3perHour             0.822059
# 9               T2 : REACTOR OUTLET Temp DEGC             0.813328
# 10  T3 : REACTOR FEED INLET Pressure KGperCM2             0.781455
# 11      T4 : Cold separator pressure KGperCM2             0.777041
# 12     T4 : FRESH FEED FLOW TO KHDS KGPerHour             0.762801
# 13      T1 : Cold separator pressure KGperCM2             0.758997
# 14     T1 : FRESH FEED FLOW TO KHDS KGPerHour             0.758551
# 15      T3 : Hydrogen make-up flow NM3perHour             0.747444
# 16      T4 : Recycle hydrogen flow NM3perHour             0.745980
# 17      T3 : Cold separator pressure KGperCM2             0.744364
# 18      T4 : Hydrogen make-up flow NM3perHour             0.742804
# 19            T1 : KERO FEED DENSITY KGperCM2             0.742692
#
#     scaled_importance  percentage
# 0            1.000000    0.039276
# 1            0.949103    0.037277
# 2            0.899897    0.035344
# 3            0.887644    0.034863
# 4            0.856817    0.033652
# 5            0.839379    0.032967
# 6            0.837825    0.032906
# 7            0.832542    0.032699
# 8            0.822059    0.032287
# 9            0.813328    0.031944
# 10           0.781455    0.030692
# 11           0.777041    0.030519
# 12           0.762801    0.029960
# 13           0.758997    0.029810
# 14           0.758551    0.029793
# 15           0.747444    0.029357
# 16           0.745980    0.029299
# 17           0.744364    0.029236
# 18           0.742804    0.029174
# 19           0.742692    0.029170
# See the whole table with table.as_data_frame()
# <bound method learning_curve_plot of >

# %%
out.mse
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DeepLearning_grid_3_AutoML_1_20220511_93953_model_1
#
#
# Status of Neuron Layers: predicting Product Sulphur, regression, gaussian distribution, Quadratic loss, 23,701 weights/biases, 292.6 KB, 46,965 training samples, mini-batch size 1
#      layer  units              type dropout   l1   l2 mean_rate  rate_rms  \
# 0        1     33             Input     5.0
# 1        2    100  RectifierDropout    10.0  0.0  0.0  0.006323  0.008727
# 2        3    100  RectifierDropout    10.0  0.0  0.0   0.00545  0.004544
# 3        4    100  RectifierDropout    10.0  0.0  0.0  0.006503  0.011616
# 4        5      1            Linear          0.0  0.0   0.00046  0.000413
#
#   momentum mean_weight weight_rms mean_bias  bias_rms
# 0
# 1      0.0    0.006528    0.13228  0.476229  0.054664
# 2      0.0   -0.011503   0.104786  0.991284  0.032594
# 3      0.0   -0.010921   0.102213  0.986081  0.024685
# 4      0.0   -0.000889    0.10739  0.107078       0.0
# ModelMetricsRegression: deeplearning
# ** Reported on train data. **
#
# MSE: 9.309600903167086
# RMSE: 3.051163860425573
# MAE: 1.3178897499166857
# RMSLE: 0.327706169149253
# Mean Residual Deviance: 9.309600903167086
#
# ModelMetricsRegression: deeplearning
# ** Reported on cross-validation data. **
#
# MSE: 12.805186068066176
# RMSE: 3.5784334656475276
# MAE: 1.5356561755395013
# RMSLE: 0.37276875522254027
# Mean Residual Deviance: 12.805186068066176
#
# Cross-Validation Metrics Summary:
#                                 mean         sd  cv_1_valid  cv_2_valid  \
# 0                     mae   1.512831   0.202720    1.378209    1.245958
# 1  mean_residual_deviance  13.339622  11.946567    5.488487    3.646299
# 2                     mse  13.339622  11.946567    5.488487    3.646299
# 3                      r2   0.425399   0.161918    0.561918    0.495553
# 4       residual_deviance  13.339622  11.946567    5.488487    3.646299
# 5                    rmse   3.378013   1.552679    2.342752    1.909528
# 6                   rmsle   0.378259   0.037738    0.354749    0.378849
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    1.540278    1.746374    1.653337
# 1   17.552038    7.582580   32.428703
# 2   17.552038    7.582580   32.428703
# 3    0.148003    0.430256    0.491265
# 4   17.552038    7.582580   32.428703
# 5    4.189516    2.753649    5.694621
# 6    0.424169    0.403989    0.329538
# Scoring History:
#                timestamp    duration training_speed     epochs  iterations  \
# 0    2022-05-11 09:49:09   0.000 sec           None   0.000000           0
# 1    2022-05-11 09:49:10  50.544 sec   3123 obs/sec   7.507937           1
# 2    2022-05-11 09:49:16  56.406 sec   4143 obs/sec  52.657848           7
# 3    2022-05-11 09:49:19  59.656 sec   4499 obs/sec  82.830688          11
#
#    samples  training_rmse  training_deviance  training_mae  training_r2
# 0      0.0            NaN                NaN           NaN          NaN
# 1   4257.0       4.534217          20.559126      2.053815     0.126172
# 2  29857.0       3.387425          11.474648      1.377257     0.512291
# 3  46965.0       3.051164           9.309601      1.317890     0.604312
# Variable Importances:
#                                      variable  relative_importance  \
# 0         T3 : Reactor inlet temperature DEGC             1.000000
# 1         T1 : Reactor inlet temperature DEGC             0.949103
# 2         T4 : Reactor inlet temperature DEGC             0.899897
# 3   T2 : REACTOR FEED INLET Pressure KGperCM2             0.887644
# 4               T3 : REACTOR OUTLET Temp DEGC             0.856817
# 5               T4 : REACTOR OUTLET Temp DEGC             0.839379
# 6               T1 : REACTOR OUTLET Temp DEGC             0.837825
# 7         T2 : Reactor inlet temperature DEGC             0.832542
# 8       T2 : Hydrogen make-up flow NM3perHour             0.822059
# 9               T2 : REACTOR OUTLET Temp DEGC             0.813328
# 10  T3 : REACTOR FEED INLET Pressure KGperCM2             0.781455
# 11      T4 : Cold separator pressure KGperCM2             0.777041
# 12     T4 : FRESH FEED FLOW TO KHDS KGPerHour             0.762801
# 13      T1 : Cold separator pressure KGperCM2             0.758997
# 14     T1 : FRESH FEED FLOW TO KHDS KGPerHour             0.758551
# 15      T3 : Hydrogen make-up flow NM3perHour             0.747444
# 16      T4 : Recycle hydrogen flow NM3perHour             0.745980
# 17      T3 : Cold separator pressure KGperCM2             0.744364
# 18      T4 : Hydrogen make-up flow NM3perHour             0.742804
# 19            T1 : KERO FEED DENSITY KGperCM2             0.742692
#
#     scaled_importance  percentage
# 0            1.000000    0.039276
# 1            0.949103    0.037277
# 2            0.899897    0.035344
# 3            0.887644    0.034863
# 4            0.856817    0.033652
# 5            0.839379    0.032967
# 6            0.837825    0.032906
# 7            0.832542    0.032699
# 8            0.822059    0.032287
# 9            0.813328    0.031944
# 10           0.781455    0.030692
# 11           0.777041    0.030519
# 12           0.762801    0.029960
# 13           0.758997    0.029810
# 14           0.758551    0.029793
# 15           0.747444    0.029357
# 16           0.745980    0.029299
# 17           0.744364    0.029236
# 18           0.742804    0.029174
# 19           0.742692    0.029170
# See the whole table with table.as_data_frame()
# <bound method ModelBase.mse of >

# %%
out.loss
# Out:
# 'automatic'

# %% [markdown]
# Now test with lesser data from Real test file which has earlier 52 data point. Now all higher than 20 r removed from test data & then check result.

# %%
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-a1c1ff8f-6c03-4bf4-860a-6e379badd096" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1c1ff8f-6c03-4bf4-860a-6e379badd096">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KHDS_TestData_12Apr_rev_2.csv to KHDS_TestData_12Apr_rev_2.csv

# %% [markdown]
# KHDS_TestData_12Apr_rev_2.csv has all values of y = Product Sulphur < = 20.
# All values above 20 from KHDS_TestData_12Apr_rev_1.csv is discarded in 2.

# %%
for fn in uploaded2.keys():
  print('User uploaded2 file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded2[fn])))
# Out:
# User uploaded2 file "KHDS_TestData_12Apr_rev_2.csv" with length 16352 bytes

# %%
new_observations_2 = h2o.import_file(path='KHDS_TestData_12Apr_rev_2.csv')
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
predictions_2 = imported_model.predict(new_observations_2)
# Out:
# generic prediction progress: |███████████████████████████████████████████████████| (done) 100%

# %%
predictions_2.head(52)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  5.87018</td></tr>
# <tr><td style="text-align: right;">  8.90026</td></tr>
# <tr><td style="text-align: right;">  6.88386</td></tr>
# <tr><td style="text-align: right;">  4.39423</td></tr>
# <tr><td style="text-align: right;">  7.66599</td></tr>
# <tr><td style="text-align: right;">  7.46432</td></tr>
# <tr><td style="text-align: right;">  6.86446</td></tr>
# <tr><td style="text-align: right;">  8.12997</td></tr>
# <tr><td style="text-align: right;">  4.04345</td></tr>
# <tr><td style="text-align: right;">  4.21162</td></tr>
# <tr><td style="text-align: right;">  4.73168</td></tr>
# <tr><td style="text-align: right;">  7.14537</td></tr>
# <tr><td style="text-align: right;">  5.77159</td></tr>
# <tr><td style="text-align: right;">  4.63258</td></tr>
# <tr><td style="text-align: right;">  4.56486</td></tr>
# <tr><td style="text-align: right;">  7.98753</td></tr>
# <tr><td style="text-align: right;">  6.63557</td></tr>
# <tr><td style="text-align: right;">  6.75626</td></tr>
# <tr><td style="text-align: right;">  8.5037 </td></tr>
# <tr><td style="text-align: right;">  7.29794</td></tr>
# <tr><td style="text-align: right;">  3.66057</td></tr>
# <tr><td style="text-align: right;">  4.79945</td></tr>
# <tr><td style="text-align: right;">  7.41656</td></tr>
# <tr><td style="text-align: right;">  4.47071</td></tr>
# <tr><td style="text-align: right;">  4.95895</td></tr>
# <tr><td style="text-align: right;">  7.36871</td></tr>
# <tr><td style="text-align: right;">  7.01803</td></tr>
# <tr><td style="text-align: right;">  4.01028</td></tr>
# <tr><td style="text-align: right;">  6.23255</td></tr>
# <tr><td style="text-align: right;">  7.06935</td></tr>
# <tr><td style="text-align: right;">  6.94322</td></tr>
# <tr><td style="text-align: right;">  3.75074</td></tr>
# <tr><td style="text-align: right;">  3.90304</td></tr>
# <tr><td style="text-align: right;">  4.06079</td></tr>
# <tr><td style="text-align: right;">  3.28366</td></tr>
# <tr><td style="text-align: right;">  4.41751</td></tr>
# <tr><td style="text-align: right;">  3.24843</td></tr>
# <tr><td style="text-align: right;">  2.89543</td></tr>
# <tr><td style="text-align: right;">  3.98997</td></tr>
# </tbody>
# </table>
